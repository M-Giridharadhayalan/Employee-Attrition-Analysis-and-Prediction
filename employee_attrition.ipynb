# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Data Science\Project-3\Employee_Attrition\.venv\Employee Details.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#seeing all columns headers
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#finding null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#checking for negative values 
(df==-1).sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#checking for duplicte values
df.duplicated().value_counts()
# Out:
# False    1470
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Target Varible for Classification : Attrition 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Attrition', data=df, palette='hot')
plt.title('Employee Attrition Distribution')
plt.show()
# Out:
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_1884\1823999183.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Attrition', data=df, palette='hot')

# %%
#Observation: since target varibale is highly imbalnced, so need to do oversampling of data set,

# %%
#EXPLORATORY DATA AANLYSIS
#Attrition with respect to department 
plt.figure(figsize=(15,5))
sns.countplot(y='Department', hue='Attrition',data=df,palette='hot')
plt.title('Employee Attrition with respect to Department')
plt.show()

# %%
sales_df = df[df['Department'] == 'Sales']
attrition_counts = sales_df['Attrition'].value_counts()
print(attrition_counts)
# Out:
# Attrition
# No     354
# Yes     92
# Name: count, dtype: int64

# %%
92/(354+92)
# Out:
# 0.2062780269058296

# %%
rd_df = df[df['Department'] == 'Research & Development']
attrition_counts = rd_df['Attrition'].value_counts()
print(attrition_counts)
# Out:
# Attrition
# No     828
# Yes    133
# Name: count, dtype: int64

# %%
133/(828+133)
# Out:
# 0.1383975026014568

# %%
hr_df = df[df['Department'] == 'Human Resources']
attrition_counts = hr_df['Attrition'].value_counts()
print(attrition_counts)
# Out:
# Attrition
# No     51
# Yes    12
# Name: count, dtype: int64

# %%
12/(63)
# Out:
# 0.19047619047619047

# %%
#Observation:realtive attrition shows sales department has high attrition percentage

# %%
#Attrition with respect to education feild
plt.figure(figsize=(15,5))
sns.countplot(y='EducationField', hue='Attrition',data=df,palette='hot')
plt.title('Employee Attrition with respect to EducationField')
plt.show()

# %%
#Attrition with respect to job role
plt.figure(figsize=(15,5))
sns.countplot(y='JobRole', hue='Attrition',data=df,palette='hot')
plt.title('Employee Attrition with respect to JobRole')
plt.show()

# %%
#Sales Department leaves the job early, and RnD people are working working more and research director has low attrition

# %%
#Attrition with respect to gender
plt.figure(figsize=(15,5))
sns.countplot(y='Gender', hue='Attrition',data=df,palette='hot')
plt.title('Employee Attrition with respect to Gender')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df['count']=1

# %%
df.groupby(['Gender','Attrition']).agg({"count":"sum"})
# Out:
#                   count
# Gender Attrition
# Female No           501
#        Yes           87
# Male   No           732
#        Yes          150

# %%
87/(588)
# Out:
# 0.14795918367346939

# %%
150/(882)
# Out:
# 0.17006802721088435

# %%
#Observation: Male has more Attrition

# %%
#Age distribution 
plt.figure(figsize=(12,5))
sns.distplot(df['Age'],hist='False')
plt.show()
# Out:
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_1884\701418579.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist='False')

# %%
#Observation: Age column are well normalized, and most the employees are between 25 to 40

# %%
#convert categorical columns into numerical columns for ML Training
categorical_columns=df.select_dtypes(include=object).columns

# %%
categorical_columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
#Binary Features are Attrition, Gender, Over 18 and Overtime
df['Attrition'] = df['Attrition'].apply(lambda x: 1 if x =='Yes'else 0)
df['Gender'] = df['Gender'].apply(lambda x: 1 if x =='Male'else 0)
df['Over18'] = df['Over18'].apply(lambda x: 1 if x =='Y'else 0)
df['OverTime'] = df['OverTime'].apply(lambda x: 1 if x =='Yes'else 0)

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#OneHot Encoding for BusinessTravel', 'Department', 'EducationField' 'JobRole', 'MaritalStatus'

df=df.join(pd.get_dummies(df['BusinessTravel'])).drop('BusinessTravel',axis=1)
df=df.join(pd.get_dummies(df['Department'],prefix=['Department'])).drop('Department',axis=1)
df=df.join(pd.get_dummies(df['EducationField'],prefix=['Education'])).drop('EducationField',axis=1)
df=df.join(pd.get_dummies(df['JobRole'],prefix=['Role'])).drop('JobRole',axis=1)
df=df.join(pd.get_dummies(df['MaritalStatus'],prefix=['Status'])).drop('MaritalStatus',axis=1)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 1465   36          0        884                23          2              1
# 1466   39          0        613                 6          1              1
# 1467   27          0        155                 4          3              1
# 1468   49          0       1023                 2          3              1
# 1469   34          0        628                 8          3              1
#
# ...

# %%
df=df.map(lambda x: 1 if x is True else 0 if x is False else x)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 1465   36          0        884                23          2              1
# 1466   39          0        613                 6          1              1
# 1467   27          0        155                 4          3              1
# 1468   49          0       1023                 2          3              1
# 1469   34          0        628                 8          3              1
#
# ...

# %%
df=df.drop('count',axis=1)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 1465   36          0        884                23          2              1
# 1466   39          0        613                 6          1              1
# 1467   27          0        155                 4          3              1
# 1468   49          0       1023                 2          3              1
# 1469   34          0        628                 8          3              1
#
# ...

# %%
df=df.drop('EmployeeNumber',axis=1)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 1465   36          0        884                23          2              1
# 1466   39          0        613                 6          1              1
# 1467   27          0        155                 4          3              1
# 1468   49          0       1023                 2          3              1
# 1469   34          0        628                 8          3              1
#
# ...

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
#Observation: EmployeeCount, Over18, StandardHours has singe variable, so it doesnt affect the target

# %%
df=df.drop(['EmployeeCount','Over18','StandardHours'],axis=1)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0      41          1       1102                 1          2
# 1      49          0        279                 8          1
# 2      37          1       1373                 2          2
# 3      33          0       1392                 3          4
# 4      27          0        591                 2          1
# ...   ...        ...        ...               ...        ...
# 1465   36          0        884                23          2
# 1466   39          0        613                 6          1
# 1467   27          0        155                 4          3
# 1468   49          0       1023                 2          3
# 1469   34          0        628                 8          3
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2       0          94               3         2
# 1                           3       1          61               2         2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 50 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Age                                    1470 non-null   int64
#  1   Attrition                              1470 non-null   int64
#  2   DailyRate                              1470 non-null   int64
#  3   DistanceFromHome                       1470 non-null   int64
#  4   Education                              1470 non-null   int64
#  5   EnvironmentSatisfaction                1470 non-null   int64
#  6   Gender                                 1470 non-null   int64
#  7   HourlyRate                             1470 non-null   int64
#  8   JobInvolvement                         1470 non-null   int64
#  9   JobLevel                               1470 non-null   int64
#  10  JobSatisfaction                        1470 non-null   int64
# ...

# %%
sns.countplot(data=df, x='Attrition',palette='Set2')
plt.title('Employee Attrition Distribution')
plt.xticks([0, 1], ['No', 'Yes'])
plt.ylabel('Number of Employees')
plt.show()

attrition_rate = df['Attrition'].value_counts(normalize=True) * 100
print("Attrition Distribution (%):\n", attrition_rate.round(2))
# Out:
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_1884\120641170.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Attrition',palette='Set2')
# Attrition Distribution (%):
#  Attrition
# 0    83.88
# 1    16.12
# Name: proportion, dtype: float64

# %%
#correlation 
corr = df.corr()
plt.figure(figsize=(16,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# Top correlated features with Attrition
corr_target = corr['Attrition'].drop('Attrition').sort_values(ascending=False)
print("Top Positive Correlations with Attrition:\n", corr_target.head())
print("\nTop Negative Correlations with Attrition:\n", corr_target.tail())
# Out:
# Top Positive Correlations with Attrition:
#  OverTime                          0.246118
# ['Status']_Single                 0.175419
# ['Role']_Sales Representative     0.157234
# Travel_Frequently                 0.115143
# ['Role']_Laboratory Technician    0.098290
# Name: Attrition, dtype: float64
#
# Top Negative Correlations with Attrition:
#  Age                  -0.159205
# MonthlyIncome        -0.159840
# YearsInCurrentRole   -0.160545
# JobLevel             -0.169105
# TotalWorkingYears    -0.171063
# Name: Attrition, dtype: float64

# %%
#Numerical Features vs Attrition
features = ['Age', 'DistanceFromHome', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany']

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='Attrition', y=feature, data=df,palette='Set2')
    plt.title(f'{feature} vs. Attrition')
    plt.xticks([0, 1], ['No', 'Yes'])
    plt.show()
# Out:
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_1884\3788433930.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=feature, data=df,palette='Set2')
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_1884\3788433930.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=feature, data=df,palette='Set2')
# C:\Users\MGiri\AppData\Local\Temp\ipykernel_1884\3788433930.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=feature, data=df,palette='Set2')
# ...

# %%
#Statistical Analysis
#We use hypothesis testing to find statistically significant differences:

#T-test for numeric features (e.g., Age)
#Chi-squared test for categorical features (e.g., OverTime)

# %%
from scipy.stats import ttest_ind
attr_yes = df[df['Attrition'] == 1]['Age']
attr_no = df[df['Attrition'] == 0]['Age']
t_stat, p_val = ttest_ind(attr_yes, attr_no)
print(f"T-test p-value for Age vs Attrition: {p_val:.5f}")
# Out:
# T-test p-value for Age vs Attrition: 0.00000

# %%
# Chi-squared test: OverTime vs Attrition
from scipy.stats import chi2_contingency
ct = pd.crosstab(df['OverTime'], df['Attrition'])
chi2, p, dof, ex = chi2_contingency(ct)
print(f"Chi-squared p-value for OverTime vs Attrition: {p:.5f}")
# Out:
# Chi-squared p-value for OverTime vs Attrition: 0.00000

# %%
# EDA INSIGHTS
#Attrition Rate: ~16% of employees left the company.
#Top Factors Correlated with Attrition:OverTime (positive),MonthlyIncome (negative),TotalWorkingYears (negative)
#DistanceFromHome (positive),YearsAtCompany (negative)
#Statistical Significance:
#Age has a significant difference (p < 0.05) between attrition groups.
#OverTime is significantly associated with attrition (p < 0.05).
#Employees who left tend to:Work more overtime,Be younger,Have fewer total working years and lower income

# %%
#MACHINE LEARNING MODELING
#Features&Traget

x = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8027210884353742

# %%
#confusion_matrix
from sklearn.metrics import confusion_matrix
y_prediction = lr.predict(x_test)
cm=confusion_matrix(y_test,y_prediction)

# %%
cm
# Out:
# array([[235,   1],
#        [ 57,   1]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89       236
#            1       0.50      0.02      0.03        58
#
#     accuracy                           0.80       294
#    macro avg       0.65      0.51      0.46       294
# weighted avg       0.74      0.80      0.72       294

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(x_test,y_test)
# Out:
# 0.8299319727891157

# %%
#confusion_matrix
from sklearn.metrics import confusion_matrix
ry_prediction = rfc.predict(x_test)
rcm=confusion_matrix(y_test,ry_prediction)

# %%
rcm
# Out:
# array([[234,   2],
#        [ 48,  10]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(rcm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,ry_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90       236
#            1       0.83      0.17      0.29        58
#
#     accuracy                           0.83       294
#    macro avg       0.83      0.58      0.59       294
# weighted avg       0.83      0.83      0.78       294

# %%
#OVERSAMPLING 
from imblearn.over_sampling import RandomOverSampler
Over_Sampling= RandomOverSampler()
x_resample,y_resample=Over_Sampling.fit_resample(x,y)

# %%
x_resample.shape
# Out:
# (2466, 49)

# %%
y_resample.shape
# Out:
# (2466,)

# %%
x = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
lr_resample=LogisticRegression()
lr_resample.fit(x_resample,y_resample)
# Out:
# d:\Data Science\Project-3\Employee_Attrition\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_resample.score(x_test,y_test)
# Out:
# 0.6054421768707483

# %%
import pickle 
with open("attrition_log.pkl", "wb") as h:
    pickle.dump(lr, h)

# %%
import pickle 
with open("attrition_rfc.pkl", "wb") as e:
    pickle.dump(rfc, e)

# %%
import joblib
# Save Logistic Regression model
joblib.dump(lr, 'logistic_model.pkl')

# Save Random Forest model
joblib.dump(rfc, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0      41          1       1102                 1          2
# 1      49          0        279                 8          1
# 2      37          1       1373                 2          2
# 3      33          0       1392                 3          4
# 4      27          0        591                 2          1
# ...   ...        ...        ...               ...        ...
# 1465   36          0        884                23          2
# 1466   39          0        613                 6          1
# 1467   27          0        155                 4          3
# 1468   49          0       1023                 2          3
# 1469   34          0        628                 8          3
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2       0          94               3         2
# 1                           3       1          61               2         2
# ...

# %%
import pickle 
with open('attrition_feature_columns.pkl', 'wb') as n:
    pickle.dump(list(x.columns), n)
